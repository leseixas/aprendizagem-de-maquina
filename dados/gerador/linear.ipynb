# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# import random

# %%
xs = np.array([90*np.random.random() for i in range(15)])
xs.sort()
print(xs)
# Out:
# [ 9.83281881 10.60314488 20.89817869 24.972238   25.00927178 36.40723423
#  46.74725749 49.77520656 52.68544934 58.7370194  71.16037954 75.75797267
#  78.93333551 85.84834884 85.91978355]

# %%
noise= np.array([10*np.random.random() for _ in range(15)])

# %%
ys = 0.8*xs+noise

# %%
# pandas
df = pd.DataFrame(xs, columns=['x'])
df['y'] = ys
# print(df)

df.to_csv("../exemplo_linear.csv") # saving DataFrame

# Loading DataFrame
# df = pd.read_csv("../exemplo_linear.csv")

# %%
import seaborn as sns
sns.set_style("ticks")

plt.scatter(xs,ys, s=100, color="#2c7fb8", edgecolors="black", linewidths=1.5, alpha=0.8)

plt.ylim(0,100)
plt.xlim(0,100)
plt.xlabel('$x$', fontsize=18)  
plt.ylabel('$y$', fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=18, width=2)
plt.gca().set_aspect('equal', adjustable='box')

for spine in plt.gca().spines.values():
    spine.set_linewidth(2)

plt.savefig("../../graficos/exemplo_linear/valores.png", dpi=600, format='png', bbox_inches='tight')
plt.show()

# %%
from sklearn.linear_model import LinearRegression

X, y = df[['x']], df[['y']]

model = LinearRegression()

model.fit(X, y)
# Out:
# LinearRegression()

# %%
a, b = model.coef_, model.intercept_

# %%
linear_model = a*np.arange(0,101,5) + b

print(linear_model)
# Out:
# [[ 3.19435814  7.27677008 11.35918201 15.44159395 19.52400589 23.60641782
#   27.68882976 31.7712417  35.85365363 39.93606557 44.01847751 48.10088944
#   52.18330138 56.26571332 60.34812525 64.43053719 68.51294913 72.59536106
#   76.677773   80.76018494 84.84259687]]

# %%
sns.set_style("ticks")

plt.scatter(xs,ys, s=100, color="#2c7fb8", edgecolors="black", linewidths=1.5, alpha=0.8)
plt.plot(np.arange(0,101,5), linear_model.ravel(), color='black', linestyle='--', linewidth=2.5)


plt.ylim(0,100)
plt.xlim(0,100)
plt.xlabel('$x$', fontsize=18)  
plt.ylabel('$y$', fontsize=18)
plt.tick_params(axis='both', which='major', labelsize=18, width=2)
plt.gca().set_aspect('equal', adjustable='box')

for spine in plt.gca().spines.values():
    spine.set_linewidth(2)

# plt.savefig("../../graficos/exemplo_linear/valores.png", dpi=600, format='png', bbox_inches='tight')
plt.show()
